# %%
import pandas as pd
import os

# %%
files = [
    'ACP-Households-by-County-January-December-2022.xlsx',
    'ACP-Households-by-County-January-July-2023.xlsx'
]

# %%
# df = pd.DataFrame()

# for file in files:
#     print(file)
df = pd.concat(pd.read_excel(os.path.join('data', file)) for file in files)

# %%
df
# Out:
#       Data Month State      State Name        County Name  State FIPS  \
# 0     2022-01-01    AL         ALABAMA     AUTAUGA COUNTY           1
# 1     2022-01-01    AL         ALABAMA     BALDWIN COUNTY           1
# 2     2022-01-01    AL         ALABAMA     BARBOUR COUNTY           1
# 3     2022-01-01    AL         ALABAMA        BIBB COUNTY           1
# 4     2022-01-01    AL         ALABAMA      BLOUNT COUNTY           1
# ...          ...   ...             ...                ...         ...
# 22954 2023-07-01    PR     PUERTO RICO  **NOT AVAILABLE**          72
# 22955 2023-07-01    VI  VIRGIN ISLANDS   ST. CROIX ISLAND          78
# 22956 2023-07-01    VI  VIRGIN ISLANDS    ST. JOHN ISLAND          78
# 22957 2023-07-01    VI  VIRGIN ISLANDS  ST. THOMAS ISLAND          78
# 22958 2023-07-01    VI  VIRGIN ISLANDS  **NOT AVAILABLE**          78
#
#              County FIPS  \
# 0                    001
# 1                    003
# 2                    005
# 3                    007
# 4                    009
# ...                  ...
# 22954  **NOT AVAILABLE**
# 22955                010
# 22956                020
# 22957                030
# 22958  **NOT AVAILABLE**
#
#        Net New Enrollments Alternative Verification Process  \
# 0                                                   46.0
# 1                                                  -13.0
# 2                                                   41.0
# 3                                                    0.0
# 4                                                   12.0
# ...                                                  ...
# 22954                                                0.0
# 22955                                                0.0
# 22956                                                0.0
# 22957                                                0.0
# 22958                                                0.0
#
#        Net New Enrollments Verified by School  Net New Enrollments Lifeline  \
# 0                                        -1.0                          20.0
# 1                                         0.0                          78.0
# 2                                         0.0                          56.0
# 3                                         0.0                          14.0
# 4                                        -1.0                          18.0
# ...                                       ...                           ...
# 22954                                     0.0                         122.0
# 22955                                     0.0                          -3.0
# 22956                                     0.0                           0.0
# 22957                                     0.0                           5.0
# 22958                                     0.0                           0.0
#
#        Net New Enrollments National Verifier Application  \
# 0                                                   53.0
# 1                                                  114.0
# 2                                                   25.0
# 3                                                   23.0
# 4                                                   46.0
# ...                                                  ...
# 22954                                               13.0
# 22955                                              178.0
# 22956                                                1.0
# 22957                                               57.0
# 22958                                              -21.0
#
#        Net New Enrollments total  Total Alternative Verification Process  \
# 0                          118.0                                   618.0
# 1                          179.0                                   521.0
# 2                          122.0                                   881.0
# 3                           37.0                                     9.0
# 4                           75.0                                   196.0
# ...                          ...                                     ...
# 22954                      135.0                                     0.0
# 22955                      175.0                                     0.0
# 22956                        1.0                                     0.0
# 22957                       62.0                                     0.0
# 22958                      -21.0                                     0.0
#
#        Total Verified by School  Total Lifeline  \
# 0                           2.0           440.0
# 1                           5.0           959.0
# 2                           1.0           444.0
# 3                           5.0           182.0
# 4                          11.0           293.0
# ...                         ...             ...
# 22954                       0.0           176.0
# 22955                       0.0            87.0
# 22956                       0.0             0.0
# 22957                       0.0            73.0
# 22958                       0.0             0.0
#
#        Total National Verifier Application  Total Subscribers
# 0                                    874.0             1934.0
# 1                                   1281.0             2766.0
# 2                                    417.0             1743.0
# 3                                    304.0              500.0
# 4                                    573.0             1073.0
# ...                                    ...                ...
# 22954                                168.0              344.0
# 22955                               2547.0             2634.0
# 22956                                 47.0               47.0
# 22957                               1666.0             1739.0
# 22958                                  0.0                0.0
#
# [62235 rows x 16 columns]

# %%
df['Data Month'].value_counts().sort_index()
# Out:
# Data Month
# 2022-01-01    3263
# 2022-02-01    3265
# 2022-03-01    3266
# 2022-04-01    3267
# 2022-05-01    3267
# 2022-06-01    3270
# 2022-07-01    3280
# 2022-08-01    3280
# 2022-09-01    3279
# 2022-10-01    3280
# 2022-11-01    3280
# 2022-12-01    3279
# 2023-01-01    3278
# 2023-02-01    3278
# 2023-03-01    3278
# 2023-04-01    3280
# 2023-05-01    3282
# 2023-06-01    3282
# 2023-07-01    3281
# Name: count, dtype: int64

# %%
df = df.query("State == 'WA'").reset_index(drop=True)

# %%
df.to_parquet(os.path.join('data', 'waAcp.parquet'))
