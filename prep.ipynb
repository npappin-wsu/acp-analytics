# %%
import pandas as pd
import os, itables

# %%
files = [
    'ACP-Households-by-County-January-December-2022.xlsx',
    'ACP-Households-by-County-January-October-2023.xlsx'
]

# %%
columnHint = {
    'County FIPS': str
}

# %%
# df = pd.DataFrame()

# for file in files:
#     print(file)
df = pd.concat(pd.read_excel(os.path.join('data', file), dtype=columnHint) for file in files)

# %%
df
# Out:
#       Data Month State      State Name        County Name  State FIPS  \
# 0     2022-01-01    AL         ALABAMA     AUTAUGA COUNTY           1
# 1     2022-01-01    AL         ALABAMA     BALDWIN COUNTY           1
# 2     2022-01-01    AL         ALABAMA     BARBOUR COUNTY           1
# 3     2022-01-01    AL         ALABAMA        BIBB COUNTY           1
# 4     2022-01-01    AL         ALABAMA      BLOUNT COUNTY           1
# ...          ...   ...             ...                ...         ...
# 32800 2023-10-01    PR     PUERTO RICO    Yauco Municipio          72
# 32801 2023-10-01    VI  VIRGIN ISLANDS  **NOT AVAILABLE**          78
# 32802 2023-10-01    VI  VIRGIN ISLANDS   St. Croix Island          78
# 32803 2023-10-01    VI  VIRGIN ISLANDS    St. John Island          78
# 32804 2023-10-01    VI  VIRGIN ISLANDS  St. Thomas Island          78
#
#       County FIPS  Net New Enrollments Alternative Verification Process  \
# ...

# %%
df[df['State'] == 'WA']['Data Month'].value_counts().sort_index()
# Out:
# Data Month
# 2022-01-01    40
# 2022-02-01    40
# 2022-03-01    40
# 2022-04-01    40
# 2022-05-01    40
# 2022-06-01    40
# 2022-07-01    40
# 2022-08-01    40
# 2022-09-01    40
# 2022-10-01    40
# 2022-11-01    40
# 2022-12-01    40
# 2023-01-01    40
# 2023-02-01    40
# 2023-03-01    40
# 2023-04-01    40
# 2023-05-01    40
# 2023-06-01    40
# 2023-07-01    40
# 2023-08-01    40
# 2023-09-01    40
# 2023-10-01    40
# Name: count, dtype: int64

# %%
df = df.query("State == 'WA'").reset_index(drop=True)

# %%
# This line is to fix september of 2023... it is sad.
df['County FIPS'] = df['County FIPS'].str.pad(3, side='left', fillchar='0')
df['County Name'] = df['County Name'].str.upper()

# %%
itables.show(df)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="f0caa2d9-9598-4fcd-bd4d-2f96de45a805" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>Data Month</th>
#       <th>State</th>
#       <th>State Name</th>
#       <th>County Name</th>
#       <th>State FIPS</th>
#       <th>County FIPS</th>
#       <th>Net New Enrollments Alternative Verification Process</th>
#       <th>Net New Enrollments Verified by School</th>
#       <th>Net New Enrollments Lifeline</th>
#       <th>Net New Enrollments National Verifier Application</th>
# ...

# %%
eshAcpStats = pd.read_csv(os.path.join('data', 'ESH_ACP Estimates.csv'), dtype={'fipsCountyCode': str})

# %%
eshAcpStats
# Out:
#                  County fipsCountyCode  Eligible Households  \
# 0          Adams County            001                 1701
# 1         Asotin County            003                 1904
# 2         Benton County            005                26617
# 3         Chelan County            007                 7482
# 4        Clallam County            009                 5803
# 5          Clark County            011                50345
# 6       Columbia County            013                  622
# 7        Cowlitz County            015                11511
# 8        Douglas County            017                 2776
# 9          Ferry County            019                  232
# 10      Franklin County            021                 9886
# 11      Garfield County            023                  349
# 12         Grant County            025                 8995
# 13  Grays Harbor County            027                 8584
# 14        Island County            029                 6556
# ...

# %%
# eshAcpStats.County = eshAcpStats.County.str.upper()

# %%
eshAcpStats
# Out:
#                  County fipsCountyCode  Eligible Households  \
# 0          Adams County            001                 1701
# 1         Asotin County            003                 1904
# 2         Benton County            005                26617
# 3         Chelan County            007                 7482
# 4        Clallam County            009                 5803
# 5          Clark County            011                50345
# 6       Columbia County            013                  622
# 7        Cowlitz County            015                11511
# 8        Douglas County            017                 2776
# 9          Ferry County            019                  232
# 10      Franklin County            021                 9886
# 11      Garfield County            023                  349
# 12         Grant County            025                 8995
# 13  Grays Harbor County            027                 8584
# 14        Island County            029                 6556
# ...

# %%
df.info()
eshAcpStats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 16 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Data Month                                            880 non-null    datetime64[ns]
#  1   State                                                 880 non-null    object
#  2   State Name                                            880 non-null    object
#  3   County Name                                           880 non-null    object
#  4   State FIPS                                            880 non-null    int64
#  5   County FIPS                                           880 non-null    object
#  6   Net New Enrollments Alternative Verification Process  880 non-null    float64
#  7   Net New Enrollments Verified by School                880 non-null    float64
# ...

# %%
df = df.merge(eshAcpStats, how='inner', left_on='County FIPS', right_on='fipsCountyCode')

# %%
itables.show(df[df.County == 'Adams County'])
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="8bbe3f12-48c4-4820-9ed3-088117b46459" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Data Month</th>
#       <th>State</th>
#       <th>State Name</th>
#       <th>County Name</th>
#       <th>State FIPS</th>
#       <th>County FIPS</th>
#       <th>Net New Enrollments Alternative Verification Process</th>
#       <th>Net New Enrollments Verified by School</th>
#       <th>Net New Enrollments Lifeline</th>
# ...

# %%
itables.show(df['County'].value_counts())
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="51e1bcc1-679b-4df7-9017-41a100af630a" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>County</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
# ...

# %%
df.to_parquet(os.path.join('data', 'waAcp.parquet'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 858 entries, 0 to 857
# Data columns (total 21 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Data Month                                            858 non-null    datetime64[ns]
#  1   State                                                 858 non-null    object
#  2   State Name                                            858 non-null    object
#  3   County Name                                           858 non-null    object
#  4   State FIPS                                            858 non-null    int64
#  5   County FIPS                                           858 non-null    object
#  6   Net New Enrollments Alternative Verification Process  858 non-null    float64
#  7   Net New Enrollments Verified by School                858 non-null    float64
# ...
