# %%
import pandas as pd
import os, itables

# %%
df = pd.read_excel(os.path.join('data', 'ACP-Households-by-County-January-December-2022.xlsx'))

# %%
itables.show(df)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="55e05739-e705-4967-8f5a-410a725b4208" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>Data Month</th>
#       <th>State</th>
#       <th>State Name</th>
#       <th>County Name</th>
#       <th>State FIPS</th>
#       <th>County FIPS</th>
#       <th>Net New Enrollments Alternative Verification Process</th>
#       <th>Net New Enrollments Verified by School</th>
#       <th>Net New Enrollments Lifeline</th>
#       <th>Net New Enrollments National Verifier Application</th>
# ...

# %%
subset = df.query("State == 'WA' and `County Name` == 'ADAMS COUNTY'")
itables.show(subset)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="af3aea5d-0ada-4d88-bb40-8ad78ecdf67d" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Data Month</th>
#       <th>State</th>
#       <th>State Name</th>
#       <th>County Name</th>
#       <th>State FIPS</th>
#       <th>County FIPS</th>
#       <th>Net New Enrollments Alternative Verification Process</th>
#       <th>Net New Enrollments Verified by School</th>
#       <th>Net New Enrollments Lifeline</th>
# ...

# %%
subset.sort_values(by='Data Month')
# Out:
#       Data Month State  State Name   County Name  State FIPS County FIPS  \
# 3070  2022-01-01    WA  WASHINGTON  ADAMS COUNTY          53         001
# 6335  2022-02-01    WA  WASHINGTON  ADAMS COUNTY          53         001
# 9601  2022-03-01    WA  WASHINGTON  ADAMS COUNTY          53         001
# 12868 2022-04-01    WA  WASHINGTON  ADAMS COUNTY          53         001
# 16135 2022-05-01    WA  WASHINGTON  ADAMS COUNTY          53         001
# 19315 2022-06-01    WA  WASHINGTON  ADAMS COUNTY          53         001
# 22593 2022-07-01    WA  WASHINGTON  ADAMS COUNTY          53         001
# 25873 2022-08-01    WA  WASHINGTON  ADAMS COUNTY          53         001
# 29152 2022-09-01    WA  WASHINGTON  ADAMS COUNTY          53         001
# 32432 2022-10-01    WA  WASHINGTON  ADAMS COUNTY          53         001
# 35712 2022-11-01    WA  WASHINGTON  ADAMS COUNTY          53         001
# 38991 2022-12-01    WA  WASHINGTON  ADAMS COUNTY          53         001
#
# ...

# %%
subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 3070 to 38991
# Data columns (total 16 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Data Month                                            12 non-null     datetime64[ns]
#  1   State                                                 12 non-null     object
#  2   State Name                                            12 non-null     object
#  3   County Name                                           12 non-null     object
#  4   State FIPS                                            12 non-null     int64
#  5   County FIPS                                           12 non-null     object
#  6   Net New Enrollments Alternative Verification Process  12 non-null     float64
#  7   Net New Enrollments Verified by School                12 non-null     float64
# ...

# %%
subset['Total Subscribers']
# Out:
# 3070     306.0
# 6335     311.0
# 9601     335.0
# 12868    329.0
# 16135    348.0
# 19315    358.0
# 22593    373.0
# 25873    386.0
# 29152    408.0
# 32432    454.0
# 35712    494.0
# 38991    519.0
# Name: Total Subscribers, dtype: float64
